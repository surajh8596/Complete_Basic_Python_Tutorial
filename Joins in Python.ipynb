# %% [markdown]
# ## Joins
# * In Python the Merge is used to Join the 2 Data Frames

# %% [markdown]
# ### 1. Inner Join:
# * Inner join is the most common type of join.
# * It returns a dataframe with only those rows that have common characteristics.
# * This is similar to the intersection of two sets.
# ![Screenshot16151.png](attachment:Screenshot16151.png)

# %%
import pandas as pd

# %%
df1=pd.read_csv("D:\PGP IN DATA SCIENCE with Careerera\Data Sets\men2004.csv")
df1.head()
# Out:
#             Athlete  Medals
# 0   PHELPS, Michael       8
# 1       THORPE, Ian       4
# 2  SCHOEMAN, Roland       3
# 3    PEIRSOL, Aaron       3
# 4      CROCKER, Ian       3

# %%
df1.rename({'Medals':'Medals_in_2004'}, axis=1, inplace=True)
df1.head(2)
# Out:
#            Athlete  Medals_in_2004
# 0  PHELPS, Michael               8
# 1      THORPE, Ian               4

# %%
df2=pd.read_csv("D:\PGP IN DATA SCIENCE with Careerera\Data Sets\men2008.csv")
df2.head()
# Out:
#                Athlete  Medals
# 0      PHELPS, Michael       8
# 1         LOCHTE, Ryan       4
# 2       BERNARD, Alain       3
# 3      SULLIVAN, Eamon       3
# 4  LAUTERSTEIN, Andrew       3

# %%
df2.rename({'Medals':'Medals_in_2008'}, axis=1, inplace=True)
df2.head(2)
# Out:
#            Athlete  Medals_in_2008
# 0  PHELPS, Michael               8
# 1     LOCHTE, Ryan               4

# %%
inner= pd.merge(df1,df2, on='Athlete', how='inner')
inner
# Out:
#               Athlete  Medals_in_2004  Medals_in_2008
# 0     PHELPS, Michael               8               8
# 1      PEIRSOL, Aaron               3               3
# 2        CROCKER, Ian               3               1
# 3    KITAJIMA, Kosuke               3               3
# 4     HANSEN, Brendan               3               1
# 5      HACKETT, Grant               3               2
# 6        LEZAK, Jason               2               3
# 7       KELLER, Klete               2               1
# 8        LOCHTE, Ryan               2               4
# 9         VENDT, Erik               1               1
# 10  VANDERKAAY, Peter               1               2
# 11       CSEH, Laszlo               1               3
# 12      DAVIES, David               1               1
# 13    DUBOSCQ, Hugues               1               2
# 14     GANGLOFF, Mark               1               1
# 15     JENSEN, Larsen               1               1

# %% [markdown]
# ### 2. Left Outer Join:
# **With a left outer join, all the records from the first dataframe will be displayed, irrespective of whether the keys in the first dataframe can be found in the second dataframe. Whereas, for the second dataframe, only the records with the keys in the second dataframe that can be found in the first dataframe will be displayed.**
# ![Screenshot16151%20%281%29.png](attachment:Screenshot16151%20%281%29.png)

# %%
left= pd.merge(df1,df2, on='Athlete', how='left')
left
# Out:
#                        Athlete  Medals_in_2004  Medals_in_2008
# 0              PHELPS, Michael               8             8.0
# 1                  THORPE, Ian               4             NaN
# 2             SCHOEMAN, Roland               3             NaN
# 3               PEIRSOL, Aaron               3             3.0
# 4                 CROCKER, Ian               3             1.0
# 5             KITAJIMA, Kosuke               3             3.0
# 6              HANSEN, Brendan               3             1.0
# 7   VAN DEN HOOGENBAND, Pieter               3             NaN
# 8               HACKETT, Grant               3             2.0
# 9               MORITA, Tomomi               2             NaN
# 10                LEZAK, Jason               2             3.0
# 11               ROGAN, Markus               2             NaN
# 12               KELLER, Klete               2             1.0
# 13              HALL, Gary Jr.               2             NaN
# ...

# %% [markdown]
# ### 3. Right Outer Join:
# **For a right join, all the records from the second dataframe will be displayed. However, only the records with the keys in the first dataframe that can be found in the second dataframe will be displayed.**
# ![Screenshot16151%20%282%29.png](attachment:Screenshot16151%20%282%29.png)

# %%
right= pd.merge(df1,df2, on='Athlete', how='right')
right
# Out:
#                 Athlete  Medals_in_2004  Medals_in_2008
# 0       PHELPS, Michael             8.0               8
# 1          LOCHTE, Ryan             2.0               4
# 2        BERNARD, Alain             NaN               3
# 3       SULLIVAN, Eamon             NaN               3
# 4   LAUTERSTEIN, Andrew             NaN               3
# ..                  ...             ...             ...
# 57     LAGUNOV, Evgeniy             NaN               1
# 58        BERENS, Ricky             NaN               1
# 59         LURZ, Thomas             NaN               1
# 60      MALLET, Gregory             NaN               1
# 61           ZHANG, Lin             NaN               1
#
# [62 rows x 3 columns]

# %% [markdown]
# ### 4. Full Outer Join:
# **A full outer join returns all the rows from the left dataframe, all the rows from the right dataframe, and matches up rows where possible, with NaNs elsewhere. But if the dataframe is complete, then we get the same output.**
# ![Screenshot16151%20%283%29.png](attachment:Screenshot16151%20%283%29.png)

# %%
full= pd.merge(df1,df2, on='Athlete', how='outer')
full
# Out:
#               Athlete  Medals_in_2004  Medals_in_2008
# 0     PHELPS, Michael             8.0             8.0
# 1         THORPE, Ian             4.0             NaN
# 2    SCHOEMAN, Roland             3.0             NaN
# 3      PEIRSOL, Aaron             3.0             3.0
# 4        CROCKER, Ian             3.0             1.0
# ..                ...             ...             ...
# 100  LAGUNOV, Evgeniy             NaN             1.0
# 101     BERENS, Ricky             NaN             1.0
# 102      LURZ, Thomas             NaN             1.0
# 103   MALLET, Gregory             NaN             1.0
# 104        ZHANG, Lin             NaN             1.0
#
# [105 rows x 3 columns]

# %% [markdown]
# ### 5. Index Join

# %%
df3=df1.rename({'Athlete':'Player'}, axis=1)
df3.head()
# Out:
#              Player  Medals_in_2004
# 0   PHELPS, Michael               8
# 1       THORPE, Ian               4
# 2  SCHOEMAN, Roland               3
# 3    PEIRSOL, Aaron               3
# 4      CROCKER, Ian               3

# %%
index= pd.merge(df3,df2, left_on='Player', right_on='Athlete')
index
# Out:
#                Player  Medals_in_2004            Athlete  Medals_in_2008
# 0     PHELPS, Michael               8    PHELPS, Michael               8
# 1      PEIRSOL, Aaron               3     PEIRSOL, Aaron               3
# 2        CROCKER, Ian               3       CROCKER, Ian               1
# 3    KITAJIMA, Kosuke               3   KITAJIMA, Kosuke               3
# 4     HANSEN, Brendan               3    HANSEN, Brendan               1
# 5      HACKETT, Grant               3     HACKETT, Grant               2
# 6        LEZAK, Jason               2       LEZAK, Jason               3
# 7       KELLER, Klete               2      KELLER, Klete               1
# 8        LOCHTE, Ryan               2       LOCHTE, Ryan               4
# 9         VENDT, Erik               1        VENDT, Erik               1
# 10  VANDERKAAY, Peter               1  VANDERKAAY, Peter               2
# 11       CSEH, Laszlo               1       CSEH, Laszlo               3
# ...
